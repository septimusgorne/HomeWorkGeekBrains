# %% [markdown]
# # Введение в искусственные нейронные сети
# # Урок 5. Рекуррентные нейронные сети

# %% [markdown]
# ## Домашняя работа:

# %% [markdown]
# ## Практическое задание
#
# <ol>
#     <li>Попробуйте изменить параметры нейронной сети генерирующий текст таким образом, чтобы добиться генерации как можно более осмысленного текста. Пришлите лучший получившейся у вас текст и опишите, что вы предприняли, чтобы его получить. Можно использовать текст другого прозведения.</li>
#     <li>* Попробуйте на numpy реализовать нейронную сеть архитектуры LSTM</li>
#     <li>* Предложите свои варианты решения проблемы исчезающего градиента в RNN</li>
# </ol>

# %%
import numpy as np
from keras.layers import Dense, Activation
from keras.layers.recurrent import SimpleRNN, LSTM, GRU
from keras.models import Sequential
from keras.regularizers import l1


# построчное чтение из примера с текстом 
with open("alice_in_wonderland.txt", 'rb') as _in:
    lines = []
    for line in _in:
        line = line.strip().lower().decode("ascii", "ignore")
        if len(line) == 0:
            continue
        lines.append(line)
text = " ".join(lines)
chars = set([c for c in text])
nb_chars = len(chars)


# создание индекса символов и reverse mapping чтобы передвигаться между значениями numerical
# ID and a specific character. The numerical ID will correspond to a column
# ID и определенный символ. Numerical ID будет соответсвовать колонке
# число при использовании one-hot кодировки для представление входов символов
char2index = {c: i for i, c in enumerate(chars)}
index2char = {i: c for i, c in enumerate(chars)}

# для удобства выберете фиксированную длину последовательность 10 символов 
SEQLEN, STEP = 10, 1
input_chars, label_chars = [], []

# конвертация data в серии разных SEQLEN-length субпоследовательностей
for i in range(0, len(text) - SEQLEN, STEP):
    input_chars.append(text[i: i + SEQLEN])
    label_chars.append(text[i + SEQLEN])


# Вычисление one-hot encoding входных последовательностей X и следующего символа (the label) y

X = np.zeros((len(input_chars), SEQLEN, nb_chars), dtype=np.bool)
y = np.zeros((len(input_chars), nb_chars), dtype=np.bool)
for i, input_char in enumerate(input_chars):
    for j, ch in enumerate(input_char):
        X[i, j, char2index[ch]] = 1
    y[i, char2index[label_chars[i]]] = 1


# установка ряда метапамертров  для нейронной сети и процесса тренировки
BATCH_SIZE, HIDDEN_SIZE = 128, 128
NUM_ITERATIONS = 25 # 25 должно быть достаточно
NUM_EPOCHS_PER_ITERATION = 2
NUM_PREDS_PER_EPOCH = 100


# Create a super simple recurrent neural network. There is one recurrent
# layer that produces an embedding of size HIDDEN_SIZE from the one-hot
# encoded input layer. This is followed by a Dense fully-connected layer
# across the set of possible next characters, which is converted to a
# probability score via a standard softmax activation with a multi-class
# cross-entropy loss function linking the prediction to the one-hot
# encoding character label.

'''
Создание очень простой рекуррентной нейронной сети. В ней будет один реккурентный закодированный входной слой. За ним последует полносвязный слой связанный с набором возможных следующих символов, которые конвертированы в вероятностные результаты через стандартную softmax активацию с multi-class cross-encoding loss функцию ссылающуются на предсказание one-hot encoding лейбл символа
'''

model = Sequential()
model.add(
    LSTM(  # вы можете изменить эту часть на LSTM или SimpleRNN, чтобы попробовать альтернативы
        HIDDEN_SIZE,
        return_sequences=False,
        input_shape=(SEQLEN, nb_chars),
#         dropout=0.05,
#         activity_regularizer=l1(0.001),
        unroll=True
    )
)
model.add(Dense(nb_chars))
model.add(Activation("softmax"))
model.compile(loss="categorical_crossentropy", optimizer="adam") #rmsprop


# выполнение серий тренировочных и демонстрационных итераций 
for iteration in range(NUM_ITERATIONS):

    # для каждой итерации запуск передачи данных в модель 
    print("=" * 50)
    print("Итерация #: %d" % (iteration))
    model.fit(X, y, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS_PER_ITERATION)

    # Select a random example input sequence.
    test_idx = np.random.randint(len(input_chars))
    test_chars = input_chars[test_idx]

    # для числа шагов предсказаний использование текущей тренируемой модели 
    # конструирование one-hot encoding для тестирования input и добавление предсказания.
    print("Генерация из посева: %s" % (test_chars))
    print(test_chars, end="")
    for i in range(NUM_PREDS_PER_EPOCH):

        # здесь one-hot encoding.
        X_test = np.zeros((1, SEQLEN, nb_chars))
        for j, ch in enumerate(test_chars):
            X_test[0, j, char2index[ch]] = 1

        # осуществление предсказания с помощью текущей модели.
        pred = model.predict(X_test, verbose=0)[0]
        y_pred = index2char[np.argmax(pred)]

        # вывод предсказания добавленного к тестовому примеру 
        print(y_pred, end="")

        # инкрементация тестового примера содержащего предсказание
        test_chars = test_chars[1:] + y_pred
print()
# Out:
# ==================================================
# Итерация #: 0
# Epoch 1/2
# 158773/158773 [==============================] - 26s 165us/step - loss: 2.4529
# Epoch 2/2
# 158773/158773 [==============================] - 26s 161us/step - loss: 2.0455
# Генерация из посева: r, with al
# r, with alice and the hare the hare the hare the hare the hare the hare the hare the hare the hare the hare th==================================================
# Итерация #: 1
# Epoch 1/2
# 158773/158773 [==============================] - 26s 163us/step - loss: 1.8714
# Epoch 2/2
# 158773/158773 [==============================] - 26s 163us/step - loss: 1.7474
# Генерация из посева: idea to al
# idea to alice was the mouse the mouse the mouse the mouse the mouse the mouse the mouse the mouse the mouse th==================================================
# Итерация #: 2
# Epoch 1/2
# 158773/158773 [==============================] - 26s 164us/step - loss: 1.6540
# Epoch 2/2
# 158773/158773 [==============================] - 26s 164us/step - loss: 1.5797
# Генерация из посева: des of it;
# des of it; and the mouse of the mock turtle in the rabbit a court of the mock turtle in the rabbit a court of ==================================================
# Итерация #: 3
# Epoch 1/2
# 158773/158773 [==============================] - 26s 164us/step - loss: 1.5192
# Epoch 2/2
# 158773/158773 [==============================] - 26s 165us/step - loss: 1.4674
# Генерация из посева:  had any s
#  had any she was a little said the mouse to be a little said the mouse to be a little said the mouse to be a l==================================================
# Итерация #: 4
# Epoch 1/2
# 158773/158773 [==============================] - 26s 165us/step - loss: 1.4239
# Epoch 2/2
# 158773/158773 [==============================] - 26s 165us/step - loss: 1.3866
# Генерация из посева: . what fun
# . what funty all the thing the white rabbit with the project gutenberg-tm electronic work in a said to herself==================================================
# Итерация #: 5
# Epoch 1/2
# 158773/158773 [==============================] - 26s 166us/step - loss: 1.3522
# Epoch 2/2
# 158773/158773 [==============================] - 27s 170us/step - loss: 1.3236
# Генерация из посева: elf, for s
# elf, for she had not a march hare said the king said the king said the king said the king said the king said t==================================================
# Итерация #: 6
# Epoch 1/2
# 158773/158773 [==============================] - 26s 165us/step - loss: 1.2950
# Epoch 2/2
# 158773/158773 [==============================] - 26s 165us/step - loss: 1.2710
# Генерация из посева: if my head
# if my head to herself, and the try of the project gutenberg-tm license the dormouse so alice were the treather==================================================
# Итерация #: 7
# Epoch 1/2
# 158773/158773 [==============================] - 26s 164us/step - loss: 1.2475
# Epoch 2/2
# 158773/158773 [==============================] - 26s 164us/step - loss: 1.2273
# Генерация из посева: t be shutt
# t be shutting a little birds and dont stand to the dormouse shoulders was a little birds and dont stand to the==================================================
# Итерация #: 8
# Epoch 1/2
# 158773/158773 [==============================] - 26s 165us/step - loss: 1.2066
# Epoch 2/2
# 158773/158773 [==============================] - 26s 164us/step - loss: 1.1879
# Генерация из посева:  well, its
#  well, its a project gutenberg-tm electronic works in a strook at the court, and the thing a little birds and ==================================================
# Итерация #: 9
# Epoch 1/2
# 158773/158773 [==============================] - 26s 164us/step - loss: 1.1705
# Epoch 2/2
# 158773/158773 [==============================] - 26s 164us/step - loss: 1.1527
# Генерация из посева: turtle, dr
# turtle, dreadfully got not all the other side of the great comy dont see he spoke, and the gryphon and the pro==================================================
# Итерация #: 10
# Epoch 1/2
# 158773/158773 [==============================] - 26s 164us/step - loss: 1.1367
# Epoch 2/2
# 158773/158773 [==============================] - 27s 167us/step - loss: 1.1206
# Генерация из посева: any other
# any other were all the thing at the white rabbit was sounded the work and the white rabbit was sounded the wor==================================================
# Итерация #: 11
# Epoch 1/2
# 158773/158773 [==============================] - 26s 164us/step - loss: 1.1064
# Epoch 2/2
# 158773/158773 [==============================] - 26s 165us/step - loss: 1.0920
# Генерация из посева: this must
# this must be the first that she was the project gutenberg-tm license that it was a little sharp i his sneezing==================================================
# Итерация #: 12
# Epoch 1/2
# 158773/158773 [==============================] - 26s 165us/step - loss: 1.0782
# Epoch 2/2
# 158773/158773 [==============================] - 26s 165us/step - loss: 1.0648
# Генерация из посева:  a failure
#  a failure in the same thing as i cant think the court, and then they were all that it was a little butter at ==================================================
# Итерация #: 13
# Epoch 1/2
# 158773/158773 [==============================] - 27s 168us/step - loss: 1.0517
# Epoch 2/2
# 158773/158773 [==============================] - 26s 164us/step - loss: 1.0400
# Генерация из посева: been, it s
# been, it such a nuck of a way of any long to the project gutenberg-tm electronic works in the pool of the whit==================================================
# Итерация #: 14
# Epoch 1/2
# 158773/158773 [==============================] - 26s 164us/step - loss: 1.0283
# Epoch 2/2
# 158773/158773 [==============================] - 26s 164us/step - loss: 1.0163
# Генерация из посева: ont even k
# ont even know what they were to do anything to see it so nurpoly to very much off the hander. and the triem to==================================================
# Итерация #: 15
# Epoch 1/2
# 158773/158773 [==============================] - 26s 164us/step - loss: 1.0058
# Epoch 2/2
# 158773/158773 [==============================] - 26s 164us/step - loss: 0.9947
# Генерация из посева: g-tm works
# g-tm works would not at one of the court, and then alice donations to the project gutenberg-tm license they ha==================================================
# Итерация #: 16
# Epoch 1/2
# 158773/158773 [==============================] - 26s 165us/step - loss: 0.9836
# Epoch 2/2
# 158773/158773 [==============================] - 26s 164us/step - loss: 0.9738
# Генерация из посева: t cats? fo
# t cats? for the cook to the end of the soldiers was an obfowing for happining dead! come on the sengethed the ==================================================
# Итерация #: 17
# Epoch 1/2
# 158773/158773 [==============================] - 26s 164us/step - loss: 0.9642
# Epoch 2/2
# 158773/158773 [==============================] - 26s 164us/step - loss: 0.9539
# Генерация из посева: t here bef
# t here before she had to he could think it was the party with staid and be the widest was a little shriek of t==================================================
# Итерация #: 18
# Epoch 1/2
# 158773/158773 [==============================] - 26s 164us/step - loss: 0.9451
# Epoch 2/2
# 158773/158773 [==============================] - 26s 164us/step - loss: 0.9372
# Генерация из посева: t he had t
# t he had to stop the shriek of the court, and she set to work the while seemed to herself, and was so much sur==================================================
# Итерация #: 19
# Epoch 1/2
# 158773/158773 [==============================] - 26s 164us/step - loss: 0.9270
# Epoch 2/2
# 158773/158773 [==============================] - 26s 165us/step - loss: 0.9191
# Генерация из посева: etter to h
# etter to hears how the table was she was speaking to herself, and was so much sudden by her head to see if the==================================================
# Итерация #: 20
# Epoch 1/2
# 158773/158773 [==============================] - 26s 165us/step - loss: 0.9107
# Epoch 2/2
# 158773/158773 [==============================] - 26s 165us/step - loss: 0.9032
# Генерация из посева: , but the
# , but the dormouse should you think i can dighth to say the caterpillar. well, i shant getting so undor a secc==================================================
# Итерация #: 21
# Epoch 1/2
# 158773/158773 [==============================] - 26s 163us/step - loss: 0.8954
# Epoch 2/2
# 158773/158773 [==============================] - 27s 167us/step - loss: 0.8872
# Генерация из посева: ch the wre
# ch the wremm not only saying to herself, and the project gutenberg-tm work (any way with the words dont hall a==================================================
# Итерация #: 22
# Epoch 1/2
# 158773/158773 [==============================] - 26s 167us/step - loss: 0.8796
# Epoch 2/2
# 158773/158773 [==============================] - 26s 166us/step - loss: 0.8720
# Генерация из посева: gan to fee
# gan to feel elice three little door appeared on the song the rabbit and then they were in the words dont be in==================================================
# Итерация #: 23
# Epoch 1/2
# 158773/158773 [==============================] - 26s 165us/step - loss: 0.8670
# Epoch 2/2
# 158773/158773 [==============================] - 27s 171us/step - loss: 0.8591
# Генерация из посева: ding or us
# ding or use in the trial noticed he went on in a turne: staid the mock turtle seemed to be no one she was the ==================================================
# Итерация #: 24
# Epoch 1/2
# 158773/158773 [==============================] - 26s 164us/step - loss: 0.8528
# Epoch 2/2
# 158773/158773 [==============================] - 26s 163us/step - loss: 0.8454
# Генерация из посева: ren she kn
# ren she knew that its hardly as the march hare and the little door alices appeared this done that wake you pro

# %% [markdown]
# ### Вывод
# В итоге лучшей фразой получилось с сетью LSTM:
# "ren she knew that its hardly as the march hare and the little door alices appeared this done that wake you pro"
# Перевод:
# "Рен она знала, что это вряд ли, как марш зайца и маленькие дверные Алисы появились, это сделано, чтобы разбудить вас"
#
#
#
# Пробовал добавить в сеть:
# dropout=0.05
# activity_regularizer=l1(0.001)
# Изменять параметры:
# BATCH_SIZE, HIDDEN_SIZE
# NUM_ITERATIONS
# NUM_EPOCHS_PER_ITERATION
# NUM_PREDS_PER_EPOCH
# Каких-то сильных изменений я не увидел.
